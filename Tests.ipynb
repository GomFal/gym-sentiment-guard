# %%
import re

text = "I love NLP! 😍 It's amazing 🚀."
emoji_free_text = re.sub(r'[^\w\s]', '', text)
print(emoji_free_text)
# Out:
# I love NLP  Its amazing

# %% [markdown]
# id,name,comment,rating,review_date,es_confidence
# 342,Rosmery Arrechedera,mi gym favorito e irene es un amor ❤️,5,Hace 6 meses,0.6955046057701111
# 475,Ricardo Hernández Alcalá,"unos cracks, aforo ideal",5,Hace un mes,0.4390345811843872
# 501,MARIA MARTOS DEL VALLE,"magnífico trato, por parte del personal",5,Fecha de edición: Hace 3 meses,0.610868513584137
# 823,Agatha Esber,de 10.,5,Hace 4 meses,0.8327773809432983
# 945,jordi galindo alvarez,me irá fenomenal...gracias,5,Hace un año,0.45670950412750244
# 965,Iliana Fuentes,simplemente excelente!,5,Hace un año,0.30777502059936523
# 970,Alberto Molina,está god,5,Hace un año,0.40745681524276733
# 972,KEVIN GIACOMETTO BALETA,excelente,5,Fecha de edición: Hace un año,0.25214844942092896
# 982,Margarita López,agradable,5,Hace un año,0.17026323080062866
# 984,Luis Rodriguez,recomendable 100%,5,Hace un año,0.43601641058921814
# 985,Reinaldo Perez,excelente,5,Hace un año,0.25214844942092896
# 992,Lenna Rodríguez,excelente,5,Hace un año,0.25214844942092896
# 994,David Polanco,excelente...,5,Hace un año,0.43236953020095825
# 996,uwudoblass,bien,5,Fecha de edición: Hace un año,0.8776705861091614
# 1008,Sergio Contra,que ganas!,5,Hace un año,0.48798736929893494
# 1036,Anastasia Fleming,excelente,5,Hace 5 meses,0.25214844942092896
# 1039,David Rojas,arriba,5,Hace 6 meses,0.588676393032074
